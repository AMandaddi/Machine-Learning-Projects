# %% [markdown]
# Importing Libraries

# %%
# Data analysis and wrangling
import numpy as np
import pandas as pd
import random as rnd

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Stastics
from scipy import stats as st
import pylab


# Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Machine Learning
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix , r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
df=pd.read_csv("house price.csv")

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912     1.5           0     0          3        1340
# 1         9050     2.0           0     4          5        3370
# 2        11947     1.0           0     0          4        1930
# 3         8030     1.0           0     0          4        1000
# 4        10500     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0      1955          2005      18810 Densmore Ave N
# 1               280      1921             0           709 W Blaine St
# 2                 0      1966             0  26206-26214 143rd Ave SE
# 3              1000      1963             0           857 170th Pl NE
# 4               800      1976          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0      1954          1979            501 N 143rd St
# 4596              0      1983          2009          14855 SE 10th Pl
# 4597              0      2009             0          759 Ilwaco Pl NE
# 4598           1020      1974             0         5148 S Creston St
# 4599              0      1990             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
#  17  country        4600 non-null   object
# dtypes: float64(4), int64(9), object(5)
# memory usage: 647.0+ KB

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# min       1.000000     0.000000     0.000000     1.000000   370.000000
# 25%       1.000000     0.000000     0.000000     3.000000  1190.000000
# 50%       1.500000     0.000000     0.000000     3.000000  1590.000000
# 75%       2.000000     0.000000     0.000000     4.000000  2300.000000
# max       3.500000     1.000000     4.000000     5.000000  9410.000000
#
#        sqft_basement     yr_built  yr_renovated
# count    4600.000000  4600.000000   4600.000000
# mean      312.081522  1970.786304    808.608261
# std       464.137228    29.731848    979.414536
# min         0.000000  1900.000000      0.000000
# 25%         0.000000  1951.000000      0.000000
# 50%         0.000000  1976.000000      0.000000
# 75%       610.000000  1997.000000   1999.000000
# max      4820.000000  2014.000000   2014.000000

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %% [markdown]
# Exploratory Data Analysis

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
df['bedrooms']=df['bedrooms'].astype(int)
df['bathrooms']=df['bathrooms'].astype(int)
df['price']=df['price'].astype(int)
df.head()
# Out:
#                   date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000         3          1         1340      7912
# 1  2014-05-02 00:00:00  2384000         5          2         3650      9050
# 2  2014-05-02 00:00:00   342000         3          2         1930     11947
# 3  2014-05-02 00:00:00   420000         3          2         2000      8030
# 4  2014-05-02 00:00:00   550000         4          2         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
plt.figure(figsize=(15,10))
plt.title("CITY VS PRICE")
sns.barplot(x='city',y='price',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df['bedrooms'].value_counts()
# Out:
# bedrooms
# 3    2032
# 4    1531
# 2     566
# 5     353
# 6      61
# 1      38
# 7      14
# 8       2
# 0       2
# 9       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16,10))
plt.title("house bedrooms distribution")
sns.countplot(x='bedrooms',data=df)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.title("Price vs Bedrooms")
sns.scatterplot(x='bedrooms',y='price',data=df,palette='Set2');

# %%
df['bathrooms'].value_counts()
# Out:
# bathrooms
# 2    2311
# 1    1666
# 3     502
# 4      82
# 0      19
# 5      15
# 6       4
# 8       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16,10))
plt.title("house bathrooms distribution")
sns.countplot(x='bathrooms',data=df,palette="mako_r")
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.title("Price vs Bathrooms")
sns.scatterplot(x='bathrooms',y='price',data=df,palette='Set2');

# %%
df['floors']=df['floors'].astype(int)

# %%
df['floors'].value_counts()
# Out:
# floors
# 1    2618
# 2    1852
# 3     130
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16,10))
plt.title("Floor distribution")
sns.countplot(x='floors',data=df,palette='Set1')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.title("Price vs floors")
sns.scatterplot(x='floors',y='price',data=df,palette='Set2');

# %%
df['yr_built'].value_counts()
# Out:
# yr_built
# 2006    111
# 2005    104
# 2007     93
# 2004     92
# 1978     90
#        ...
# 1915      6
# 1935      6
# 1933      5
# 1934      4
# 1936      3
# Name: count, Length: 115, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.title("Year built distribution")
sns.countplot(x='yr_built',data=df,palette='Set1')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.title("Price vs year build")
sns.scatterplot(x='yr_built',y='price',data=df,palette='Set2',hue='city');

# %%
df['Current_year']=2023
df.head()
# Out:
#                   date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000         3          1         1340      7912
# 1  2014-05-02 00:00:00  2384000         5          2         3650      9050
# 2  2014-05-02 00:00:00   342000         3          2         1930     11947
# 3  2014-05-02 00:00:00   420000         3          2         2000      8030
# 4  2014-05-02 00:00:00   550000         4          2         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0       1           0     0          3        1340              0      1955
# 1       2           0     4          5        3370            280      1921
# 2       1           0     0          4        1930              0      1966
# 3       1           0     0          4        1000           1000      1963
# 4       1           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country  \
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA
#
#    Current_year
# 0          2023
# 1          2023
# 2          2023
# 3          2023
# 4          2023

# %%
df['condition'].value_counts()
# Out:
# condition
# 3    2875
# 4    1252
# 5     435
# 2      32
# 1       6
# Name: count, dtype: int64

# %%
df
# Out:
#                      date    price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00   313000         3          1         1340
# 1     2014-05-02 00:00:00  2384000         5          2         3650
# 2     2014-05-02 00:00:00   342000         3          2         1930
# 3     2014-05-02 00:00:00   420000         3          2         2000
# 4     2014-05-02 00:00:00   550000         4          2         1940
# ...                   ...      ...       ...        ...          ...
# 4595  2014-07-09 00:00:00   308166         3          1         1510
# 4596  2014-07-09 00:00:00   534333         3          2         1460
# 4597  2014-07-09 00:00:00   416904         3          2         3010
# 4598  2014-07-10 00:00:00   203400         4          2         2090
# 4599  2014-07-10 00:00:00   220600         3          2         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912       1           0     0          3        1340
# 1         9050       2           0     4          5        3370
# 2        11947       1           0     0          4        1930
# 3         8030       1           0     0          4        1000
# 4        10500       1           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595      6360       1           0     0          4        1510
# 4596      7573       2           0     0          3        1460
# 4597      7014       2           0     0          3        3010
# 4598      6630       1           0     0          3        1070
# 4599      8102       2           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0      1955          2005      18810 Densmore Ave N
# 1               280      1921             0           709 W Blaine St
# 2                 0      1966             0  26206-26214 143rd Ave SE
# 3              1000      1963             0           857 170th Pl NE
# 4               800      1976          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0      1954          1979            501 N 143rd St
# 4596              0      1983          2009          14855 SE 10th Pl
# 4597              0      2009             0          759 Ilwaco Pl NE
# 4598           1020      1974             0         5148 S Creston St
# 4599              0      1990             0         18717 SE 258th St
#
#            city  statezip country  Current_year
# 0     Shoreline  WA 98133     USA          2023
# 1       Seattle  WA 98119     USA          2023
# 2          Kent  WA 98042     USA          2023
# 3      Bellevue  WA 98008     USA          2023
# 4       Redmond  WA 98052     USA          2023
# ...         ...       ...     ...           ...
# 4595    Seattle  WA 98133     USA          2023
# 4596   Bellevue  WA 98007     USA          2023
# 4597     Renton  WA 98059     USA          2023
# 4598    Seattle  WA 98178     USA          2023
# 4599  Covington  WA 98042     USA          2023
#
# [4600 rows x 19 columns]

# %% [markdown]
# <!-- def remove_outlier(col):
#     sorted(col)
#     Q1,Q3=np.percentile(col,[25,75])
#     IQR=Q3-Q1
#     lower_range= Q1-(1.5 * IQR)
#     upper_range= Q3+(1.5 * IQR)
#     return lower_range, upper_range -->

# %%
# def remove_outlier(col):
#     sorted(col)
#     Q1,Q3=np.percentile(col,[25,75])
#     IQR=Q3-Q1
#     lower_range= Q1-(1.5 * IQR)
#     upper_range= Q3+(1.5 * IQR)
#     return lower_range, upper_range

df['sqft_above'].value_counts()
# Out:
# sqft_above
# 1200    47
# 1010    47
# 1300    45
# 1140    44
# 1320    43
#         ..
# 2481     1
# 560      1
# 2437     1
# 3590     1
# 2538     1
# Name: count, Length: 511, dtype: int64

# %%
plt.figure(figsize=(15,15))
plt.title("Price vs Square ft_above")
sns.scatterplot(x=df['sqft_above'],y=df['price'],data=df,hue='city')
plt.show()

# %%
df.head()
# Out:
#                   date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000         3          1         1340      7912
# 1  2014-05-02 00:00:00  2384000         5          2         3650      9050
# 2  2014-05-02 00:00:00   342000         3          2         1930     11947
# 3  2014-05-02 00:00:00   420000         3          2         2000      8030
# 4  2014-05-02 00:00:00   550000         4          2         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0       1           0     0          3        1340              0      1955
# 1       2           0     4          5        3370            280      1921
# 2       1           0     0          4        1930              0      1966
# 3       1           0     0          4        1000           1000      1963
# 4       1           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country  \
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA
#
#    Current_year
# 0          2023
# 1          2023
# 2          2023
# 3          2023
# 4          2023

# %%
plt.figure(figsize=(15,15))
plt.title("Price vs Square basement")
sns.scatterplot(x=df['sqft_basement'],y=df['price'],data=df,hue='city')
plt.show()

# %% [markdown]
# Feature Engineering

# %%
df.head()
# Out:
#                   date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000         3          1         1340      7912
# 1  2014-05-02 00:00:00  2384000         5          2         3650      9050
# 2  2014-05-02 00:00:00   342000         3          2         1930     11947
# 3  2014-05-02 00:00:00   420000         3          2         2000      8030
# 4  2014-05-02 00:00:00   550000         4          2         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0       1           0     0          3        1340              0      1955
# 1       2           0     4          5        3370            280      1921
# 2       1           0     0          4        1930              0      1966
# 3       1           0     0          4        1000           1000      1963
# 4       1           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country  \
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA
#
#    Current_year
# 0          2023
# 1          2023
# 2          2023
# 3          2023
# 4          2023

# %%
df['day']=pd.to_datetime(df['date']).dt.day
df['month']=pd.to_datetime(df['date']).dt.month
df
# Out:
#                      date    price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00   313000         3          1         1340
# 1     2014-05-02 00:00:00  2384000         5          2         3650
# 2     2014-05-02 00:00:00   342000         3          2         1930
# 3     2014-05-02 00:00:00   420000         3          2         2000
# 4     2014-05-02 00:00:00   550000         4          2         1940
# ...                   ...      ...       ...        ...          ...
# 4595  2014-07-09 00:00:00   308166         3          1         1510
# 4596  2014-07-09 00:00:00   534333         3          2         1460
# 4597  2014-07-09 00:00:00   416904         3          2         3010
# 4598  2014-07-10 00:00:00   203400         4          2         2090
# 4599  2014-07-10 00:00:00   220600         3          2         1490
#
#       sqft_lot  floors  waterfront  view  condition  ...  sqft_basement  \
# 0         7912       1           0     0          3  ...              0
# 1         9050       2           0     4          5  ...            280
# 2        11947       1           0     0          4  ...              0
# 3         8030       1           0     0          4  ...           1000
# 4        10500       1           0     0          4  ...            800
# ...        ...     ...         ...   ...        ...  ...            ...
# 4595      6360       1           0     0          4  ...              0
# 4596      7573       2           0     0          3  ...              0
# 4597      7014       2           0     0          3  ...              0
# 4598      6630       1           0     0          3  ...           1020
# 4599      8102       2           0     0          4  ...              0
#
#       yr_built  yr_renovated                    street       city  statezip  \
# 0         1955          2005      18810 Densmore Ave N  Shoreline  WA 98133
# 1         1921             0           709 W Blaine St    Seattle  WA 98119
# 2         1966             0  26206-26214 143rd Ave SE       Kent  WA 98042
# 3         1963             0           857 170th Pl NE   Bellevue  WA 98008
# 4         1976          1992         9105 170th Ave NE    Redmond  WA 98052
# ...        ...           ...                       ...        ...       ...
# 4595      1954          1979            501 N 143rd St    Seattle  WA 98133
# 4596      1983          2009          14855 SE 10th Pl   Bellevue  WA 98007
# 4597      2009             0          759 Ilwaco Pl NE     Renton  WA 98059
# 4598      1974             0         5148 S Creston St    Seattle  WA 98178
# 4599      1990             0         18717 SE 258th St  Covington  WA 98042
#
#      country Current_year  day  month
# 0        USA         2023    2      5
# 1        USA         2023    2      5
# 2        USA         2023    2      5
# 3        USA         2023    2      5
# 4        USA         2023    2      5
# ...      ...          ...  ...    ...
# 4595     USA         2023    9      7
# 4596     USA         2023    9      7
# 4597     USA         2023    9      7
# 4598     USA         2023   10      7
# 4599     USA         2023   10      7
#
# [4600 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country', 'Current_year', 'day', 'month'],
#       dtype='object')

# %%
df.drop(columns=['date', 'street'], inplace=True, errors='ignore')

# %%
df
# Out:
#         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0      313000         3          1         1340      7912       1           0
# 1     2384000         5          2         3650      9050       2           0
# 2      342000         3          2         1930     11947       1           0
# 3      420000         3          2         2000      8030       1           0
# 4      550000         4          2         1940     10500       1           0
# ...       ...       ...        ...          ...       ...     ...         ...
# 4595   308166         3          1         1510      6360       1           0
# 4596   534333         3          2         1460      7573       2           0
# 4597   416904         3          2         3010      7014       2           0
# 4598   203400         4          2         2090      6630       1           0
# 4599   220600         3          2         1490      8102       2           0
#
#       view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0        0          3        1340              0      1955          2005
# 1        4          5        3370            280      1921             0
# 2        0          4        1930              0      1966             0
# 3        0          4        1000           1000      1963             0
# 4        0          4        1140            800      1976          1992
# ...    ...        ...         ...            ...       ...           ...
# 4595     0          4        1510              0      1954          1979
# 4596     0          3        1460              0      1983          2009
# 4597     0          3        3010              0      2009             0
# 4598     0          3        1070           1020      1974             0
# 4599     0          4        1490              0      1990             0
#
#            city  statezip country  Current_year  day  month
# 0     Shoreline  WA 98133     USA          2023    2      5
# 1       Seattle  WA 98119     USA          2023    2      5
# 2          Kent  WA 98042     USA          2023    2      5
# 3      Bellevue  WA 98008     USA          2023    2      5
# 4       Redmond  WA 98052     USA          2023    2      5
# ...         ...       ...     ...           ...  ...    ...
# 4595    Seattle  WA 98133     USA          2023    9      7
# 4596   Bellevue  WA 98007     USA          2023    9      7
# 4597     Renton  WA 98059     USA          2023    9      7
# 4598    Seattle  WA 98178     USA          2023   10      7
# 4599  Covington  WA 98042     USA          2023   10      7
#
# [4600 rows x 19 columns]

# %%
df['Age_of_house']=df['Current_year']-df['yr_built']

# %%
df
# Out:
#         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0      313000         3          1         1340      7912       1           0
# 1     2384000         5          2         3650      9050       2           0
# 2      342000         3          2         1930     11947       1           0
# 3      420000         3          2         2000      8030       1           0
# 4      550000         4          2         1940     10500       1           0
# ...       ...       ...        ...          ...       ...     ...         ...
# 4595   308166         3          1         1510      6360       1           0
# 4596   534333         3          2         1460      7573       2           0
# 4597   416904         3          2         3010      7014       2           0
# 4598   203400         4          2         2090      6630       1           0
# 4599   220600         3          2         1490      8102       2           0
#
#       view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0        0          3        1340              0      1955          2005
# 1        4          5        3370            280      1921             0
# 2        0          4        1930              0      1966             0
# 3        0          4        1000           1000      1963             0
# 4        0          4        1140            800      1976          1992
# ...    ...        ...         ...            ...       ...           ...
# 4595     0          4        1510              0      1954          1979
# 4596     0          3        1460              0      1983          2009
# 4597     0          3        3010              0      2009             0
# 4598     0          3        1070           1020      1974             0
# 4599     0          4        1490              0      1990             0
#
#            city  statezip country  Current_year  day  month  Age_of_house
# 0     Shoreline  WA 98133     USA          2023    2      5            68
# 1       Seattle  WA 98119     USA          2023    2      5           102
# 2          Kent  WA 98042     USA          2023    2      5            57
# 3      Bellevue  WA 98008     USA          2023    2      5            60
# 4       Redmond  WA 98052     USA          2023    2      5            47
# ...         ...       ...     ...           ...  ...    ...           ...
# 4595    Seattle  WA 98133     USA          2023    9      7            69
# 4596   Bellevue  WA 98007     USA          2023    9      7            40
# 4597     Renton  WA 98059     USA          2023    9      7            14
# 4598    Seattle  WA 98178     USA          2023   10      7            49
# 4599  Covington  WA 98042     USA          2023   10      7            33
#
# [4600 rows x 20 columns]

# %%
df.drop(columns=['yr_built'],inplace=True)
df.drop(columns=['statezip'],inplace=True)
df
# Out:
#         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0      313000         3          1         1340      7912       1           0
# 1     2384000         5          2         3650      9050       2           0
# 2      342000         3          2         1930     11947       1           0
# 3      420000         3          2         2000      8030       1           0
# 4      550000         4          2         1940     10500       1           0
# ...       ...       ...        ...          ...       ...     ...         ...
# 4595   308166         3          1         1510      6360       1           0
# 4596   534333         3          2         1460      7573       2           0
# 4597   416904         3          2         3010      7014       2           0
# 4598   203400         4          2         2090      6630       1           0
# 4599   220600         3          2         1490      8102       2           0
#
#       view  condition  sqft_above  sqft_basement  yr_renovated       city  \
# 0        0          3        1340              0          2005  Shoreline
# 1        4          5        3370            280             0    Seattle
# 2        0          4        1930              0             0       Kent
# 3        0          4        1000           1000             0   Bellevue
# 4        0          4        1140            800          1992    Redmond
# ...    ...        ...         ...            ...           ...        ...
# 4595     0          4        1510              0          1979    Seattle
# 4596     0          3        1460              0          2009   Bellevue
# 4597     0          3        3010              0             0     Renton
# 4598     0          3        1070           1020             0    Seattle
# 4599     0          4        1490              0             0  Covington
#
#      country  Current_year  day  month  Age_of_house
# 0        USA          2023    2      5            68
# 1        USA          2023    2      5           102
# 2        USA          2023    2      5            57
# 3        USA          2023    2      5            60
# 4        USA          2023    2      5            47
# ...      ...           ...  ...    ...           ...
# 4595     USA          2023    9      7            69
# 4596     USA          2023    9      7            40
# 4597     USA          2023    9      7            14
# 4598     USA          2023   10      7            49
# 4599     USA          2023   10      7            33
#
# [4600 rows x 18 columns]

# %%
# a = pd.get_dummies(df['city'], prefix = "city")
b = pd.get_dummies(df['country'], prefix = "country")

# %%
frames = [df, b]
df = pd.concat(frames, axis = 1)
df.head()
# Out:
#      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000         3          1         1340      7912       1           0
# 1  2384000         5          2         3650      9050       2           0
# 2   342000         3          2         1930     11947       1           0
# 3   420000         3          2         2000      8030       1           0
# 4   550000         4          2         1940     10500       1           0
#
#    view  condition  sqft_above  sqft_basement  yr_renovated       city  \
# 0     0          3        1340              0          2005  Shoreline
# 1     4          5        3370            280             0    Seattle
# 2     0          4        1930              0             0       Kent
# 3     0          4        1000           1000             0   Bellevue
# 4     0          4        1140            800          1992    Redmond
#
#   country  Current_year  day  month  Age_of_house  country_USA
# 0     USA          2023    2      5            68         True
# 1     USA          2023    2      5           102         True
# 2     USA          2023    2      5            57         True
# 3     USA          2023    2      5            60         True
# 4     USA          2023    2      5            47         True

# %%
df.drop(columns=['country'],inplace=True)
df
# Out:
#         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0      313000         3          1         1340      7912       1           0
# 1     2384000         5          2         3650      9050       2           0
# 2      342000         3          2         1930     11947       1           0
# 3      420000         3          2         2000      8030       1           0
# 4      550000         4          2         1940     10500       1           0
# ...       ...       ...        ...          ...       ...     ...         ...
# 4595   308166         3          1         1510      6360       1           0
# 4596   534333         3          2         1460      7573       2           0
# 4597   416904         3          2         3010      7014       2           0
# 4598   203400         4          2         2090      6630       1           0
# 4599   220600         3          2         1490      8102       2           0
#
#       view  condition  sqft_above  sqft_basement  yr_renovated       city  \
# 0        0          3        1340              0          2005  Shoreline
# 1        4          5        3370            280             0    Seattle
# 2        0          4        1930              0             0       Kent
# 3        0          4        1000           1000             0   Bellevue
# 4        0          4        1140            800          1992    Redmond
# ...    ...        ...         ...            ...           ...        ...
# 4595     0          4        1510              0          1979    Seattle
# 4596     0          3        1460              0          2009   Bellevue
# 4597     0          3        3010              0             0     Renton
# 4598     0          3        1070           1020             0    Seattle
# 4599     0          4        1490              0             0  Covington
#
#       Current_year  day  month  Age_of_house  country_USA
# 0             2023    2      5            68         True
# 1             2023    2      5           102         True
# 2             2023    2      5            57         True
# 3             2023    2      5            60         True
# 4             2023    2      5            47         True
# ...            ...  ...    ...           ...          ...
# 4595          2023    9      7            69         True
# 4596          2023    9      7            40         True
# 4597          2023    9      7            14         True
# 4598          2023   10      7            49         True
# 4599          2023   10      7            33         True
#
# [4600 rows x 18 columns]

# %%
df.drop(columns=['city'],inplace=True)
df
# Out:
#         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0      313000         3          1         1340      7912       1           0
# 1     2384000         5          2         3650      9050       2           0
# 2      342000         3          2         1930     11947       1           0
# 3      420000         3          2         2000      8030       1           0
# 4      550000         4          2         1940     10500       1           0
# ...       ...       ...        ...          ...       ...     ...         ...
# 4595   308166         3          1         1510      6360       1           0
# 4596   534333         3          2         1460      7573       2           0
# 4597   416904         3          2         3010      7014       2           0
# 4598   203400         4          2         2090      6630       1           0
# 4599   220600         3          2         1490      8102       2           0
#
#       view  condition  sqft_above  sqft_basement  yr_renovated  Current_year  \
# 0        0          3        1340              0          2005          2023
# 1        4          5        3370            280             0          2023
# 2        0          4        1930              0             0          2023
# 3        0          4        1000           1000             0          2023
# 4        0          4        1140            800          1992          2023
# ...    ...        ...         ...            ...           ...           ...
# 4595     0          4        1510              0          1979          2023
# 4596     0          3        1460              0          2009          2023
# 4597     0          3        3010              0             0          2023
# 4598     0          3        1070           1020             0          2023
# 4599     0          4        1490              0             0          2023
#
#       day  month  Age_of_house  country_USA
# 0       2      5            68         True
# 1       2      5           102         True
# 2       2      5            57         True
# 3       2      5            60         True
# 4       2      5            47         True
# ...   ...    ...           ...          ...
# 4595    9      7            69         True
# 4596    9      7            40         True
# 4597    9      7            14         True
# 4598   10      7            49         True
# 4599   10      7            33         True
#
# [4600 rows x 17 columns]

# %% [markdown]
# Selection of dependent and independent

# %%
x=df.drop(columns=['price'])
y=df['price']

# %%
x
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0            3          1         1340      7912       1           0     0
# 1            5          2         3650      9050       2           0     4
# 2            3          2         1930     11947       1           0     0
# 3            3          2         2000      8030       1           0     0
# 4            4          2         1940     10500       1           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 4595         3          1         1510      6360       1           0     0
# 4596         3          2         1460      7573       2           0     0
# 4597         3          2         3010      7014       2           0     0
# 4598         4          2         2090      6630       1           0     0
# 4599         3          2         1490      8102       2           0     0
#
#       condition  sqft_above  sqft_basement  yr_renovated  Current_year  day  \
# 0             3        1340              0          2005          2023    2
# 1             5        3370            280             0          2023    2
# 2             4        1930              0             0          2023    2
# 3             4        1000           1000             0          2023    2
# 4             4        1140            800          1992          2023    2
# ...         ...         ...            ...           ...           ...  ...
# 4595          4        1510              0          1979          2023    9
# 4596          3        1460              0          2009          2023    9
# 4597          3        3010              0             0          2023    9
# 4598          3        1070           1020             0          2023   10
# 4599          4        1490              0             0          2023   10
#
#       month  Age_of_house  country_USA
# 0         5            68         True
# 1         5           102         True
# 2         5            57         True
# 3         5            60         True
# 4         5            47         True
# ...     ...           ...          ...
# 4595      7            69         True
# 4596      7            40         True
# 4597      7            14         True
# 4598      7            49         True
# 4599      7            33         True
#
# [4600 rows x 16 columns]

# %%
y
# Out:
# 0        313000
# 1       2384000
# 2        342000
# 3        420000
# 4        550000
#          ...
# 4595     308166
# 4596     534333
# 4597     416904
# 4598     203400
# 4599     220600
# Name: price, Length: 4600, dtype: int64

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_renovated', 'Current_year', 'day', 'month', 'Age_of_house',
#        'country_USA'],
#       dtype='object')

# %%
sd=StandardScaler()
x_scaled=sd.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=22)

# %%
x_train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 2958         4          2         2320     11717       2           0     0
# 1632         2          1         1880      7560       1           0     0
# 1564         4          1         1640      4240       1           0     0
# 1959         3          1         1150      4825       1           0     0
# 831          1          1         1140      6700       1           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 2527         3          1         1110     12150       1           0     0
# 2952         4          2         2200      7700       1           0     0
# 4587         2          1          770      8149       1           0     0
# 356          6          3         3510      5760       2           0     0
# 2933         4          3         3940     27591       2           0     3
#
#       condition  sqft_above  sqft_basement  yr_renovated  Current_year  day  \
# 2958          3        2320              0             0          2023   20
# 1632          3         940            940          2001          2023   30
# 1564          5         920            720             0          2023   29
# 1959          4        1150              0          2001          2023    5
# 831           3        1140              0          1979          2023   16
# ...         ...         ...            ...           ...           ...  ...
# 2527          4        1110              0          2001          2023   15
# 2952          3        1100           1100          2014          2023   20
# 4587          3         770              0          1994          2023    8
# 356           4        3510              0          1990          2023    8
# 2933          3        3440            500             0          2023   20
#
#       month  Age_of_house  country_USA
# 2958      6            26         True
# 1632      5           104         True
# 1564      5           102         True
# 1959      6            66         True
# 831       5           103         True
# ...     ...           ...          ...
# 2527      6            66         True
# 2952      6            44         True
# 4587      7            75         True
# 356       5           117         True
# 2933      6            23         True
#
# [3680 rows x 16 columns]

# %%
x_test
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 245          3          2         1760      9055       2           0     0
# 1497         2          1          740      9003       1           0     0
# 512          3          1         1080      8100       1           0     0
# 1778         5          2         2040      7488       1           0     0
# 4096         3          2          960      9380       1           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 4073         3          1         1400      8100       1           0     0
# 2805         3          1         1510      4800       1           0     2
# 1227         2          1         1300     11867       1           0     0
# 4105         3          1         1180     16552       1           0     0
# 3614         3          1         1200      9087       1           0     0
#
#       condition  sqft_above  sqft_basement  yr_renovated  Current_year  day  \
# 245           4        1760              0             0          2023    7
# 1497          3         740              0          1998          2023   28
# 512           4        1080              0          2009          2023   12
# 1778          4        1200            840             0          2023    3
# 4096          3         960              0          1998          2023    8
# ...         ...         ...            ...           ...           ...  ...
# 4073          3        1400              0             0          2023    8
# 2805          3         860            650          2011          2023   18
# 1227          4        1300              0             0          2023   23
# 4105          4        1180              0             0          2023    8
# 3614          5        1200              0             0          2023   28
#
#       month  Age_of_house  country_USA
# 245       5            38         True
# 1497      5            74         True
# 512       5            68         True
# 1778      6            54         True
# 4096      7            74         True
# ...     ...           ...          ...
# 4073      7            79         True
# 2805      6            98         True
# 1227      5            48         True
# 4105      7            56         True
# 3614      6            54         True
#
# [920 rows x 16 columns]

# %%
y_train
# Out:
# 2958     397000
# 1632     280000
# 1564     635200
# 1959     240000
# 831      540000
#          ...
# 2527     416000
# 2952     279000
# 4587     229629
# 356     1750000
# 2933     725000
# Name: price, Length: 3680, dtype: int64

# %%
y_test
# Out:
# 245     460000
# 1497    157500
# 512     339000
# 1778    449500
# 4096    210000
#          ...
# 4073    267000
# 2805    465000
# 1227    225000
# 4105    390000
# 3614    339900
# Name: price, Length: 920, dtype: int64

# %%
training_score=[]
testing_score=[]

# %%
def model_pred_unscaled(model):
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    y_pred_train=model.predict(x_train)
    a = accuracy_score(y_train,y_pred_train)*100
    b = accuracy_score(y_test,y_pred)*100
    a.astype(int)
    b.astype(int)
    training_score.append(a)
    testing_score.append(b)
    
    print(f"Accuracy_Score of {model} model on Training Data is:",a)
    print(f"Accuracy_Score of {model} model on Testing Data is:",b)
    print("\n------------------------------------------------------------------------")

# %%
model_pred_unscaled(DecisionTreeClassifier())
# Out:
# Accuracy_Score of DecisionTreeClassifier() model on Training Data is: 100.0
# Accuracy_Score of DecisionTreeClassifier() model on Testing Data is: 0.10869565217391304
#
# ------------------------------------------------------------------------

# %%
model_pred_scaled(KNeighborsClassifier())
# Out:
# Accuracy_Score of KNeighborsClassifier() model on Training Data is: 18.559782608695652
# Accuracy_Score of KNeighborsClassifier() model on Testing Data is: 0.43478260869565216
#
# ------------------------------------------------------------------------

# %%
def model_pred_scaled(model):
    model.fit(x_train1,y_train1)
    y_pred1=model.predict(x_test1)
    y_pred_train1=model.predict(x_train1)
    a = accuracy_score(y_train1,y_pred_train1)*100
    b = accuracy_score(y_test1,y_pred1)*100
    a.astype(int)
    b.astype(int)
    training_score.append(a)
    testing_score.append(b)
        
    print(f"Accuracy_Score of {model} model on Training Data is:",a)
    print(f"Accuracy_Score of {model} model on Testing Data is:",b)
    print("\n------------------------------------------------------------------------")

# %%
x_train1,x_test1,y_train1,y_test1=train_test_split(x_scaled,y,test_size=0.2,random_state=22)

# %%
model_pred_scaled(LogisticRegression())
# Out:
# Accuracy_Score of LogisticRegression() model on Training Data is: 10.625
# Accuracy_Score of LogisticRegression() model on Testing Data is: 0.43478260869565216
#
# ------------------------------------------------------------------------

# %%
model_pred_scaled(KNeighborsClassifier())
# Out:
# Accuracy_Score of KNeighborsClassifier() model on Training Data is: 18.559782608695652
# Accuracy_Score of KNeighborsClassifier() model on Testing Data is: 0.43478260869565216
#
# ------------------------------------------------------------------------

# %%
model_pred_scaled(SVC())
# Out:
# Accuracy_Score of SVC() model on Training Data is: 5.923913043478261
# Accuracy_Score of SVC() model on Testing Data is: 1.0869565217391304
#
# ------------------------------------------------------------------------

# %%
model_pred_scaled(GaussianNB())
# Out:
# Accuracy_Score of GaussianNB() model on Training Data is: 35.434782608695656
# Accuracy_Score of GaussianNB() model on Testing Data is: 0.10869565217391304
#
# ------------------------------------------------------------------------

# %%
models=['Decision Tree','Random Forest','ADA boosting','LGBM','Logistic Regression','KNN','SVC','Gaussian Naiye bayes']

# %%
training_score
# Out:
# [100.0,
#  100.0,
#  1.5217391304347827,
#  1.5217391304347827,
#  1.5217391304347827,
#  10.625,
#  18.559782608695652,
#  5.923913043478261,
#  35.434782608695656,
#  18.559782608695652,
#  18.559782608695652]

# %%
testing_score
# Out:
# [0.10869565217391304,
#  0.32608695652173914,
#  0.9782608695652175,
#  0.9782608695652175,
#  0.9782608695652175,
#  0.43478260869565216,
#  0.43478260869565216,
#  1.0869565217391304,
#  0.10869565217391304,
#  0.43478260869565216,
#  0.43478260869565216]
